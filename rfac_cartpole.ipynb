# %%
#@title Imports
from IPython.display import clear_output
import time
import numpy as np
import math
from collections import namedtuple
import random
from tqdm.notebook import tqdm
import torch
import torch.nn as nn   
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim   
import torch.nn.functional as F
from matplotlib import pyplot as plt
from math import pi as pi
random.seed(2)
torch.manual_seed(2)
np.random.seed(2)

# %%
#@title Choose device
device = 'cuda'

# %%
#@title Cartpole Environment
class Cartpole:
    def __init__(self, init_state, action_interval):
        self.m1 = 0.5
        self.m2 = 0.5
        self.l = 0.6
        self.b = 0.1
        self.g = 9.82
        self.dt = 0.01
        self.Tinv = torch.tensor([[1., self.l, 0.],
                                  [self.l, self.l**2, 0.], 
                                  [0., 0., self.l**2]])
        self.jtarget = torch.tensor([0., 0., 1.])
        self.T = action_interval
        self.action_time = int(self.T/self.dt)
        self.init_state = init_state.clone().detach()
        self.current_state = init_state.clone().detach()

        self.action_space = torch.linspace(-10, 10, 11)
        self.n_actions = len(self.action_space)

    def reset(self, ):
        self.current_state = self.init_state.clone().detach()


    def euler_step(self, action):
        x = self.current_state
        x[2] = -x[2]+pi;
        x = (x + self.dt
                * (torch.tensor([
                                 x[1], 
                                 (2*self.m2*self.l*x[3]**2*torch.sin(x[2]) + 3*self.m2*self.g*torch.sin(x[2])*torch.cos(x[2]) 
                                 + 4*action - 4*self.b*x[1])/(4*(self.m1+self.m2) - 3*self.m2*torch.cos(x[2])**2), 
                                 x[3], 
                                 (-3*self.m2*self.l*x[3]**2*torch.sin(x[2])*torch.cos(x[2]) - 6*(self.m1+self.m2)*self.g*torch.sin(x[2]) 
                                 - 6*(action-self.b*x[1])*torch.cos(x[2]))/(4*self.l*(self.m1+self.m2) - 3*self.m2*self.l*torch.cos(x[2])**2)
                                 ])
                    )
             )
                
        # Check boundaries
        # pos
        if x[0] > 6:
            x[0] = 6
            x[1] = -0.5*x[1]
        elif x[0] < -6:
            x[0] = -6
            x[1] = -0.5*x[1]
        
        # pos_dot
        if x[1] > 10:
            x[1] = 10
        elif x[1] < -10:
            x[1] = -10
        
        # theta
        x[2] = -(x[2]-pi)
        if x[2] > pi:
            x[2] = -(2*pi - x[2])
        elif x[2] < -pi:
            x[2] = (2*pi + x[2])
        
        # theta_dot
        if x[3] > 10:
            x[3] = 10
        elif x[3] < -10:
            x[3] = -10

        self.current_state = x

    def step(self, action_idx):
        action = self.action_space[action_idx]
        for _ in range(self.action_time):
            self.euler_step(action)
        x = self.current_state
        j = torch.tensor([x[0], torch.sin(x[2]), torch.cos(x[2])])
        jj = j - self.jtarget
        reward = torch.tensor([-(1-torch.exp(-0.5*(jj @ self.Tinv @ jj.T )))])
        return self.current_state, reward
def test():
    x = torch.zeros(T_test,4)
    r = torch.zeros(T_test,1)
    actor_net.eval()
    env.reset()                   
    for t in range(T_test):
        with torch.no_grad():
            action = select_action(env.current_state.to(device).unsqueeze(0),greedy=True)
        x[t], r[t] = env.step(action)
    return sum(r), x

# %%
#@title Memory
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))
class ReplayMemory(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
#@title Select action
def select_action(state, greedy = False):
    actor_net.eval()
    with torch.no_grad():
        action_weights = actor_net(state)
        if greedy:
            return action_weights.max(1)[1].unsqueeze(0)
        else: 
            return torch.multinomial(F.softmax(action_weights, dim=1), 1,  replacement = True)

# %%
#@title Update networks
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return 0, 0           

    # Sample mini-batch from memory buffer
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions))

    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)
    next_state_batch = torch.cat(batch.next_state)

    # Compute loss critic
    critic_net.train()
    optimizer_critic.zero_grad() 
    with torch.no_grad():
        next_state_values = target_critic_net(next_state_batch)
        expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    loss_critic = F.mse_loss(critic_net(state_batch), expected_state_action_values)

    # Optimize critic
    loss_critic.backward()
    optimizer_critic.step()

    # Compute loss actor
    actor_net.train()
    optimizer_actor.zero_grad()
    critic_net.eval()
    with torch.no_grad():
        next_state_values = critic_net(next_state_batch)
        state_action_values = critic_net(state_batch)
        expected_state_action_values = (next_state_values * GAMMA) + reward_batch
        diff = expected_state_action_values - state_action_values
        actor_outputs = target_actor_net(state_batch)
        targets = actor_outputs.gather(1, action_batch)+BETA*diff*(1-F.softmax(actor_outputs, dim=1).gather(1, action_batch))

    loss_actor = F.mse_loss(actor_net(state_batch).gather(1, action_batch), targets)

    # Optimize actor
    loss_actor.backward()
    optimizer_actor.step()

    return loss_actor.item(), loss_critic.item()

# %%
#@title Model classes
class Actor(nn.Module):
    def __init__(self, input_dim, outputs):
        super(Actor, self).__init__()
        self.nunits = 1000
        self.h = nn.ReLU()
        self.fc1 = nn.Linear(input_dim, self.nunits)
        self.fc2 = nn.Linear(self.nunits, self.nunits)
        self.fc3 = nn.Linear(self.nunits, self.nunits)
        self.fc4 = nn.Linear(self.nunits, self.nunits)
        self.fc5 = nn.Linear(self.nunits, self.nunits)
        self.head = nn.Linear(self.nunits, outputs)

    def forward(self, x):
        x = self.h(self.fc1(x))
        x = self.h(self.fc2(x))
        x = self.h(self.fc3(x))
        x = self.h(self.fc4(x))
        x = self.h(self.fc5(x))
        return self.head(x)

class Critic(nn.Module):
    def __init__(self, input_dim):
        super(Critic, self).__init__()
        self.nunits = 100000
        self.h = nn.ReLU()
        self.fc1 = nn.Linear(input_dim, self.nunits)
        for p in self.fc1.parameters():
            p.requires_grad = False
        self.head = nn.Linear(self.nunits, 1)

    def forward(self, x):
        x = self.h(self.fc1(x))
        return self.head(x)

# %%
#@title Initialize
env = Cartpole(torch.tensor([0, 0, pi, 0,]), 0.1)
state_dim = 4
memory = ReplayMemory(250)

n_actions = env.n_actions
steps_done = 0

actor_net = Actor(state_dim, n_actions).to(device)
target_actor_net = Actor(state_dim, n_actions).to(device)
target_actor_net.load_state_dict(actor_net.state_dict())
target_actor_net.eval()

critic_net = Critic(state_dim).to(device)
target_critic_net = Critic(state_dim).to(device)
target_critic_net.load_state_dict(critic_net.state_dict())
target_critic_net.eval()

optimizer_actor = optim.Adam(actor_net.parameters(), lr=1e-4)
optimizer_critic = optim.Adam(critic_net.parameters(), lr=1e-4)
acc_reward = []

# %%
#@title Training
BATCH_SIZE = 128 
GAMMA = 0.9 
BETA = 0.6
num_episodes = 600 
episode_len = 50 
ACTOR_TARGET_UPDATE = 100 
TARGET_UPDATE = 100 
TEST_UPDATE = 1000
T_test = 50
for i_episode in tqdm(range(num_episodes)):
    loss_c = 0
    loss_a = 0
    # Initialize the environment and state
    env.reset()
    state = env.current_state.unsqueeze(0).to(device)
    for t in range(episode_len):
        # Select and perform an action
        action = select_action(state)
        next_state, reward  = env.step(action.item())
        next_state = next_state.unsqueeze(0).to(device)
        reward = reward.unsqueeze(0).to(device)

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        steps_done += 1

        # Move to the next state
        state = next_state

        # Perform one step of the optimization
        la, lc = optimize_model()
        if la:
            loss_a += la
            loss_c += lc
        # Update the target network
        if steps_done % TARGET_UPDATE == 0:
            target_critic_net.load_state_dict(critic_net.state_dict())
        if steps_done % ACTOR_TARGET_UPDATE == 0:
            target_actor_net.load_state_dict(actor_net.state_dict())
        if steps_done % TEST_UPDATE == 0 :
            r , _ = test()
            acc_reward.append(r)
            print(r)
    print('Episode {}, Steps {}, BETA {:.1f}: actor-loss {:.2e}, critic-loss {:.2e}'.format(i_episode, steps_done, BETA, loss_a/episode_len, loss_c/episode_len))
print('Complete')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))
# Episode 0, Steps 50, BETA 0.6: actor-loss 0.00e+00, critic-loss 0.00e+00
# Episode 1, Steps 100, BETA 0.6: actor-loss 0.00e+00, critic-loss 0.00e+00
# Episode 2, Steps 150, BETA 0.6: actor-loss 1.36e-01, critic-loss 3.98e+00
# Episode 3, Steps 200, BETA 0.6: actor-loss 2.69e-02, critic-loss 4.27e-01
# Episode 4, Steps 250, BETA 0.6: actor-loss 3.11e-02, critic-loss 1.53e-01
# Episode 5, Steps 300, BETA 0.6: actor-loss 5.76e-03, critic-loss 6.68e-02
# Episode 6, Steps 350, BETA 0.6: actor-loss 2.24e-02, critic-loss 1.30e-01
# Episode 7, Steps 400, BETA 0.6: actor-loss 2.71e-03, critic-loss 4.93e-02
# Episode 8, Steps 450, BETA 0.6: actor-loss 2.02e-02, critic-loss 9.70e-02
# Episode 9, Steps 500, BETA 0.6: actor-loss 2.97e-03, critic-loss 4.09e-02
# Episode 10, Steps 550, BETA 0.6: actor-loss 1.37e-02, critic-loss 7.20e-02
# Episode 11, Steps 600, BETA 0.6: actor-loss 2.00e-03, critic-loss 4.13e-02
# Episode 12, Steps 650, BETA 0.6: actor-loss 1.40e-02, critic-loss 7.25e-02
# Episode 13, Steps 700, BETA 0.6: actor-loss 3.00e-03, critic-loss 3.89e-02
# Episode 14, Steps 750, BETA 0.6: actor-loss 1.18e-02, critic-loss 7.17e-02
# Episode 15, Steps 800, BETA 0.6: actor-loss 1.96e-03, critic-loss 4.36e-02
# Episode 16, Steps 850, BETA 0.6: actor-loss 1.19e-02, critic-loss 7.61e-02
# Episode 17, Steps 900, BETA 0.6: actor-loss 2.72e-03, critic-loss 5.95e-02
# Episode 18, Steps 950, BETA 0.6: actor-loss 9.62e-03, critic-loss 5.97e-02
# tensor([-25.6320])
# Episode 19, Steps 1000, BETA 0.6: actor-loss 2.57e-03, critic-loss 4.99e-02
# Episode 20, Steps 1050, BETA 0.6: actor-loss 1.51e-02, critic-loss 7.80e-02
# Episode 21, Steps 1100, BETA 0.6: actor-loss 4.10e-03, critic-loss 5.97e-02
# Episode 22, Steps 1150, BETA 0.6: actor-loss 2.02e-02, critic-loss 1.44e-01
# Episode 23, Steps 1200, BETA 0.6: actor-loss 7.25e-03, critic-loss 7.68e-02
# Episode 24, Steps 1250, BETA 0.6: actor-loss 1.22e-02, critic-loss 9.48e-02
# Episode 25, Steps 1300, BETA 0.6: actor-loss 4.43e-03, critic-loss 7.82e-02
# Episode 26, Steps 1350, BETA 0.6: actor-loss 1.34e-02, critic-loss 9.18e-02
# Episode 27, Steps 1400, BETA 0.6: actor-loss 6.85e-03, critic-loss 7.42e-02
# Episode 28, Steps 1450, BETA 0.6: actor-loss 1.08e-02, critic-loss 9.55e-02
# Episode 29, Steps 1500, BETA 0.6: actor-loss 2.08e-02, critic-loss 1.69e-01
# Episode 30, Steps 1550, BETA 0.6: actor-loss 1.12e-02, critic-loss 8.73e-02
# Episode 31, Steps 1600, BETA 0.6: actor-loss 7.04e-03, critic-loss 7.87e-02
# Episode 32, Steps 1650, BETA 0.6: actor-loss 1.43e-02, critic-loss 1.55e-01
# Episode 33, Steps 1700, BETA 0.6: actor-loss 9.28e-03, critic-loss 1.05e-01
# Episode 34, Steps 1750, BETA 0.6: actor-loss 2.09e-02, critic-loss 1.72e-01
# Episode 35, Steps 1800, BETA 0.6: actor-loss 1.53e-02, critic-loss 1.37e-01
# Episode 36, Steps 1850, BETA 0.6: actor-loss 1.43e-02, critic-loss 1.46e-01
# Episode 37, Steps 1900, BETA 0.6: actor-loss 7.63e-03, critic-loss 1.27e-01
# Episode 38, Steps 1950, BETA 0.6: actor-loss 2.71e-02, critic-loss 3.08e-01
# tensor([-15.9536])
# Episode 39, Steps 2000, BETA 0.6: actor-loss 1.65e-02, critic-loss 1.92e-01
# Episode 40, Steps 2050, BETA 0.6: actor-loss 1.71e-02, critic-loss 1.62e-01
# Episode 41, Steps 2100, BETA 0.6: actor-loss 7.95e-03, critic-loss 9.91e-02
# Episode 42, Steps 2150, BETA 0.6: actor-loss 7.11e-03, critic-loss 7.31e-02
# Episode 43, Steps 2200, BETA 0.6: actor-loss 3.92e-03, critic-loss 6.60e-02
# Episode 44, Steps 2250, BETA 0.6: actor-loss 8.87e-03, critic-loss 1.04e-01
# Episode 45, Steps 2300, BETA 0.6: actor-loss 5.21e-03, critic-loss 6.14e-02
# Episode 46, Steps 2350, BETA 0.6: actor-loss 1.04e-02, critic-loss 7.29e-02
# Episode 47, Steps 2400, BETA 0.6: actor-loss 1.24e-02, critic-loss 1.05e-01
# Episode 48, Steps 2450, BETA 0.6: actor-loss 2.73e-02, critic-loss 1.27e-01
# Episode 49, Steps 2500, BETA 0.6: actor-loss 9.26e-03, critic-loss 1.19e-01
# Episode 50, Steps 2550, BETA 0.6: actor-loss 1.10e-02, critic-loss 1.20e-01
# Episode 51, Steps 2600, BETA 0.6: actor-loss 8.53e-03, critic-loss 1.05e-01
# Episode 52, Steps 2650, BETA 0.6: actor-loss 2.10e-02, critic-loss 1.78e-01
# Episode 53, Steps 2700, BETA 0.6: actor-loss 1.69e-02, critic-loss 2.87e-01
# Episode 54, Steps 2750, BETA 0.6: actor-loss 1.12e-02, critic-loss 1.65e-01
# Episode 55, Steps 2800, BETA 0.6: actor-loss 3.97e-03, critic-loss 8.41e-02
# Episode 56, Steps 2850, BETA 0.6: actor-loss 1.10e-02, critic-loss 1.07e-01
# Episode 57, Steps 2900, BETA 0.6: actor-loss 8.14e-03, critic-loss 1.18e-01
# Episode 58, Steps 2950, BETA 0.6: actor-loss 1.06e-02, critic-loss 9.11e-02
# tensor([-13.9953])
# Episode 59, Steps 3000, BETA 0.6: actor-loss 5.51e-03, critic-loss 6.64e-02
# Episode 60, Steps 3050, BETA 0.6: actor-loss 1.72e-02, critic-loss 8.51e-02
# Episode 61, Steps 3100, BETA 0.6: actor-loss 3.06e-03, critic-loss 4.96e-02
# Episode 62, Steps 3150, BETA 0.6: actor-loss 5.70e-03, critic-loss 4.17e-02
# Episode 63, Steps 3200, BETA 0.6: actor-loss 3.03e-03, critic-loss 4.70e-02
# Episode 64, Steps 3250, BETA 0.6: actor-loss 1.04e-02, critic-loss 4.90e-02
# Episode 65, Steps 3300, BETA 0.6: actor-loss 5.47e-03, critic-loss 4.76e-02
# Episode 66, Steps 3350, BETA 0.6: actor-loss 7.82e-02, critic-loss 6.62e-01
# Episode 67, Steps 3400, BETA 0.6: actor-loss 1.01e-02, critic-loss 6.42e-02
# Episode 68, Steps 3450, BETA 0.6: actor-loss 2.94e-03, critic-loss 3.62e-02
# Episode 69, Steps 3500, BETA 0.6: actor-loss 1.76e-03, critic-loss 4.45e-02
# Episode 70, Steps 3550, BETA 0.6: actor-loss 3.49e-03, critic-loss 4.21e-02
# Episode 71, Steps 3600, BETA 0.6: actor-loss 1.53e-03, critic-loss 3.01e-02
# Episode 72, Steps 3650, BETA 0.6: actor-loss 4.93e-03, critic-loss 4.11e-02
# Episode 73, Steps 3700, BETA 0.6: actor-loss 2.77e-03, critic-loss 3.73e-02
# Episode 74, Steps 3750, BETA 0.6: actor-loss 5.57e-03, critic-loss 5.25e-02
# Episode 75, Steps 3800, BETA 0.6: actor-loss 5.83e-03, critic-loss 5.11e-02
# Episode 76, Steps 3850, BETA 0.6: actor-loss 2.36e-02, critic-loss 2.95e-01
# Episode 77, Steps 3900, BETA 0.6: actor-loss 3.26e-02, critic-loss 3.73e-01
# Episode 78, Steps 3950, BETA 0.6: actor-loss 4.76e-03, critic-loss 4.38e-02
# tensor([-13.0712])
# Episode 79, Steps 4000, BETA 0.6: actor-loss 3.83e-03, critic-loss 8.06e-02
# Episode 80, Steps 4050, BETA 0.6: actor-loss 1.02e-02, critic-loss 7.26e-02
# Episode 81, Steps 4100, BETA 0.6: actor-loss 6.96e-03, critic-loss 7.91e-02
# Episode 82, Steps 4150, BETA 0.6: actor-loss 9.80e-03, critic-loss 1.27e-01
# Episode 83, Steps 4200, BETA 0.6: actor-loss 4.81e-03, critic-loss 8.03e-02
# Episode 84, Steps 4250, BETA 0.6: actor-loss 1.19e-02, critic-loss 1.09e-01
# Episode 85, Steps 4300, BETA 0.6: actor-loss 7.93e-03, critic-loss 9.32e-02
# Episode 86, Steps 4350, BETA 0.6: actor-loss 1.07e-02, critic-loss 8.68e-02
# Episode 87, Steps 4400, BETA 0.6: actor-loss 1.32e-02, critic-loss 1.46e-01
# Episode 88, Steps 4450, BETA 0.6: actor-loss 1.55e-02, critic-loss 7.70e-02
# Episode 89, Steps 4500, BETA 0.6: actor-loss 1.29e-02, critic-loss 1.87e-01
# Episode 90, Steps 4550, BETA 0.6: actor-loss 3.23e-02, critic-loss 3.43e-01
# Episode 91, Steps 4600, BETA 0.6: actor-loss 7.49e-03, critic-loss 8.55e-02
# Episode 92, Steps 4650, BETA 0.6: actor-loss 1.03e-02, critic-loss 8.43e-02
# Episode 93, Steps 4700, BETA 0.6: actor-loss 2.84e-03, critic-loss 5.89e-02
# Episode 94, Steps 4750, BETA 0.6: actor-loss 1.09e-02, critic-loss 1.03e-01
# Episode 95, Steps 4800, BETA 0.6: actor-loss 2.29e-03, critic-loss 5.18e-02
# Episode 96, Steps 4850, BETA 0.6: actor-loss 5.53e-03, critic-loss 6.29e-02
# Episode 97, Steps 4900, BETA 0.6: actor-loss 4.14e-03, critic-loss 5.24e-02
# Episode 98, Steps 4950, BETA 0.6: actor-loss 4.60e-03, critic-loss 4.93e-02
# tensor([-12.5431])
# Episode 99, Steps 5000, BETA 0.6: actor-loss 1.60e-03, critic-loss 3.67e-02
# Episode 100, Steps 5050, BETA 0.6: actor-loss 8.72e-03, critic-loss 7.68e-02
# Episode 101, Steps 5100, BETA 0.6: actor-loss 9.42e-03, critic-loss 1.07e-01
# Episode 102, Steps 5150, BETA 0.6: actor-loss 2.28e-02, critic-loss 2.69e-01
# Episode 103, Steps 5200, BETA 0.6: actor-loss 1.17e-02, critic-loss 1.15e-01
# Episode 104, Steps 5250, BETA 0.6: actor-loss 1.34e-02, critic-loss 1.46e-01
# Episode 105, Steps 5300, BETA 0.6: actor-loss 4.97e-03, critic-loss 9.45e-02
# Episode 106, Steps 5350, BETA 0.6: actor-loss 1.15e-02, critic-loss 1.07e-01
# Episode 107, Steps 5400, BETA 0.6: actor-loss 1.02e-02, critic-loss 1.31e-01
# Episode 108, Steps 5450, BETA 0.6: actor-loss 1.05e-02, critic-loss 9.71e-02
# Episode 109, Steps 5500, BETA 0.6: actor-loss 6.34e-03, critic-loss 8.33e-02
# Episode 110, Steps 5550, BETA 0.6: actor-loss 3.48e-02, critic-loss 4.74e-01
# Episode 111, Steps 5600, BETA 0.6: actor-loss 8.80e-03, critic-loss 1.03e-01
# Episode 112, Steps 5650, BETA 0.6: actor-loss 8.33e-03, critic-loss 7.59e-02
# Episode 113, Steps 5700, BETA 0.6: actor-loss 4.86e-03, critic-loss 6.62e-02
# Episode 114, Steps 5750, BETA 0.6: actor-loss 6.65e-03, critic-loss 6.02e-02
# Episode 115, Steps 5800, BETA 0.6: actor-loss 6.60e-03, critic-loss 7.46e-02
# Episode 116, Steps 5850, BETA 0.6: actor-loss 5.97e-03, critic-loss 4.47e-02
# Episode 117, Steps 5900, BETA 0.6: actor-loss 4.54e-03, critic-loss 6.46e-02
# Episode 118, Steps 5950, BETA 0.6: actor-loss 5.08e-03, critic-loss 5.15e-02
# tensor([-14.1199])
# Episode 119, Steps 6000, BETA 0.6: actor-loss 6.76e-03, critic-loss 9.68e-02
# Episode 120, Steps 6050, BETA 0.6: actor-loss 6.39e-02, critic-loss 8.75e-01
# Episode 121, Steps 6100, BETA 0.6: actor-loss 2.52e-02, critic-loss 2.91e-01
# Episode 122, Steps 6150, BETA 0.6: actor-loss 4.51e-03, critic-loss 6.80e-02
# Episode 123, Steps 6200, BETA 0.6: actor-loss 1.81e-03, critic-loss 6.20e-02
# Episode 124, Steps 6250, BETA 0.6: actor-loss 5.17e-03, critic-loss 7.17e-02
# Episode 125, Steps 6300, BETA 0.6: actor-loss 1.88e-03, critic-loss 4.98e-02
# Episode 126, Steps 6350, BETA 0.6: actor-loss 5.60e-03, critic-loss 5.84e-02
# Episode 127, Steps 6400, BETA 0.6: actor-loss 1.51e-03, critic-loss 3.94e-02
# Episode 128, Steps 6450, BETA 0.6: actor-loss 4.59e-03, critic-loss 4.31e-02
# Episode 129, Steps 6500, BETA 0.6: actor-loss 2.66e-03, critic-loss 4.31e-02
# Episode 130, Steps 6550, BETA 0.6: actor-loss 1.24e-02, critic-loss 1.06e-01
# Episode 131, Steps 6600, BETA 0.6: actor-loss 6.54e-03, critic-loss 9.41e-02
# Episode 132, Steps 6650, BETA 0.6: actor-loss 1.31e-02, critic-loss 1.63e-01
# Episode 133, Steps 6700, BETA 0.6: actor-loss 4.29e-03, critic-loss 8.67e-02
# Episode 134, Steps 6750, BETA 0.6: actor-loss 1.50e-02, critic-loss 1.90e-01
# Episode 135, Steps 6800, BETA 0.6: actor-loss 1.09e-02, critic-loss 1.69e-01
# Episode 136, Steps 6850, BETA 0.6: actor-loss 1.48e-02, critic-loss 1.10e-01
# Episode 137, Steps 6900, BETA 0.6: actor-loss 5.93e-03, critic-loss 7.58e-02
# Episode 138, Steps 6950, BETA 0.6: actor-loss 2.04e-02, critic-loss 2.51e-01
# tensor([-15.4306])
# Episode 139, Steps 7000, BETA 0.6: actor-loss 1.21e-02, critic-loss 1.37e-01
# Episode 140, Steps 7050, BETA 0.6: actor-loss 7.46e-03, critic-loss 7.13e-02
# Episode 141, Steps 7100, BETA 0.6: actor-loss 2.38e-03, critic-loss 5.86e-02
# Episode 142, Steps 7150, BETA 0.6: actor-loss 5.09e-03, critic-loss 7.01e-02
# Episode 143, Steps 7200, BETA 0.6: actor-loss 2.61e-03, critic-loss 6.01e-02
# Episode 144, Steps 7250, BETA 0.6: actor-loss 4.21e-03, critic-loss 4.40e-02
# Episode 145, Steps 7300, BETA 0.6: actor-loss 3.31e-03, critic-loss 4.99e-02
# Episode 146, Steps 7350, BETA 0.6: actor-loss 4.99e-03, critic-loss 5.19e-02
# Episode 147, Steps 7400, BETA 0.6: actor-loss 3.99e-03, critic-loss 4.38e-02
# Episode 148, Steps 7450, BETA 0.6: actor-loss 5.22e-03, critic-loss 4.14e-02
# Episode 149, Steps 7500, BETA 0.6: actor-loss 3.63e-03, critic-loss 4.98e-02
# Episode 150, Steps 7550, BETA 0.6: actor-loss 6.41e-03, critic-loss 6.38e-02
# Episode 151, Steps 7600, BETA 0.6: actor-loss 4.72e-03, critic-loss 5.54e-02
# Episode 152, Steps 7650, BETA 0.6: actor-loss 4.74e-03, critic-loss 5.09e-02
# Episode 153, Steps 7700, BETA 0.6: actor-loss 2.79e-03, critic-loss 4.19e-02
# Episode 154, Steps 7750, BETA 0.6: actor-loss 1.30e-02, critic-loss 9.27e-02
# Episode 155, Steps 7800, BETA 0.6: actor-loss 5.13e-03, critic-loss 6.11e-02
# Episode 156, Steps 7850, BETA 0.6: actor-loss 1.22e-02, critic-loss 7.03e-02
# Episode 157, Steps 7900, BETA 0.6: actor-loss 4.62e-03, critic-loss 4.38e-02
# Episode 158, Steps 7950, BETA 0.6: actor-loss 7.19e-03, critic-loss 7.61e-02
# tensor([-13.3994])
# Episode 159, Steps 8000, BETA 0.6: actor-loss 7.07e-03, critic-loss 7.67e-02
# Episode 160, Steps 8050, BETA 0.6: actor-loss 2.55e-02, critic-loss 3.66e-01
# Episode 161, Steps 8100, BETA 0.6: actor-loss 2.99e-02, critic-loss 2.38e-01
# Episode 162, Steps 8150, BETA 0.6: actor-loss 2.80e-02, critic-loss 3.36e-01
# Episode 163, Steps 8200, BETA 0.6: actor-loss 4.89e-03, critic-loss 7.33e-02
# Episode 164, Steps 8250, BETA 0.6: actor-loss 1.08e-02, critic-loss 1.16e-01
# Episode 165, Steps 8300, BETA 0.6: actor-loss 1.11e-02, critic-loss 1.75e-01
# Episode 166, Steps 8350, BETA 0.6: actor-loss 8.11e-03, critic-loss 8.97e-02
# Episode 167, Steps 8400, BETA 0.6: actor-loss 4.58e-03, critic-loss 7.46e-02
# Episode 168, Steps 8450, BETA 0.6: actor-loss 1.41e-02, critic-loss 1.36e-01
# Episode 169, Steps 8500, BETA 0.6: actor-loss 8.47e-03, critic-loss 1.13e-01
# Episode 170, Steps 8550, BETA 0.6: actor-loss 7.24e-03, critic-loss 9.30e-02
# Episode 171, Steps 8600, BETA 0.6: actor-loss 4.11e-03, critic-loss 9.27e-02
# Episode 172, Steps 8650, BETA 0.6: actor-loss 9.37e-03, critic-loss 9.61e-02
# Episode 173, Steps 8700, BETA 0.6: actor-loss 4.73e-03, critic-loss 8.20e-02
# Episode 174, Steps 8750, BETA 0.6: actor-loss 6.71e-03, critic-loss 8.17e-02
# Episode 175, Steps 8800, BETA 0.6: actor-loss 5.44e-03, critic-loss 9.29e-02
# Episode 176, Steps 8850, BETA 0.6: actor-loss 5.84e-03, critic-loss 8.43e-02
# Episode 177, Steps 8900, BETA 0.6: actor-loss 1.16e-02, critic-loss 1.63e-01
# Episode 178, Steps 8950, BETA 0.6: actor-loss 3.75e-03, critic-loss 3.92e-02
# tensor([-10.0476])
# Episode 179, Steps 9000, BETA 0.6: actor-loss 2.71e-03, critic-loss 5.20e-02
# Episode 180, Steps 9050, BETA 0.6: actor-loss 9.96e-03, critic-loss 9.93e-02
# Episode 181, Steps 9100, BETA 0.6: actor-loss 2.83e-02, critic-loss 4.83e-01
# Episode 182, Steps 9150, BETA 0.6: actor-loss 2.77e-02, critic-loss 2.65e-01
# Episode 183, Steps 9200, BETA 0.6: actor-loss 8.46e-03, critic-loss 1.21e-01
# Episode 184, Steps 9250, BETA 0.6: actor-loss 9.52e-03, critic-loss 7.88e-02
# Episode 185, Steps 9300, BETA 0.6: actor-loss 3.78e-03, critic-loss 7.08e-02
# Episode 186, Steps 9350, BETA 0.6: actor-loss 9.76e-03, critic-loss 9.78e-02
# Episode 187, Steps 9400, BETA 0.6: actor-loss 5.06e-03, critic-loss 7.66e-02
# Episode 188, Steps 9450, BETA 0.6: actor-loss 8.52e-03, critic-loss 7.71e-02
# Episode 189, Steps 9500, BETA 0.6: actor-loss 3.23e-03, critic-loss 5.24e-02
# Episode 190, Steps 9550, BETA 0.6: actor-loss 7.33e-03, critic-loss 7.05e-02
# Episode 191, Steps 9600, BETA 0.6: actor-loss 1.34e-02, critic-loss 1.40e-01
# Episode 192, Steps 9650, BETA 0.6: actor-loss 3.10e-02, critic-loss 2.25e-01
# Episode 193, Steps 9700, BETA 0.6: actor-loss 4.81e-03, critic-loss 3.48e-02
# Episode 194, Steps 9750, BETA 0.6: actor-loss 3.53e-03, critic-loss 5.40e-02
# Episode 195, Steps 9800, BETA 0.6: actor-loss 3.39e-03, critic-loss 5.04e-02
# Episode 196, Steps 9850, BETA 0.6: actor-loss 6.34e-03, critic-loss 5.36e-02
# Episode 197, Steps 9900, BETA 0.6: actor-loss 4.20e-03, critic-loss 4.48e-02
# Episode 198, Steps 9950, BETA 0.6: actor-loss 5.87e-03, critic-loss 5.90e-02
# tensor([-10.2632])
# Episode 199, Steps 10000, BETA 0.6: actor-loss 4.81e-03, critic-loss 6.34e-02
# Episode 200, Steps 10050, BETA 0.6: actor-loss 2.97e-02, critic-loss 4.65e-01
# Episode 201, Steps 10100, BETA 0.6: actor-loss 4.58e-02, critic-loss 4.51e-01
# Episode 202, Steps 10150, BETA 0.6: actor-loss 3.72e-03, critic-loss 4.09e-02
# Episode 203, Steps 10200, BETA 0.6: actor-loss 1.84e-03, critic-loss 4.45e-02
# Episode 204, Steps 10250, BETA 0.6: actor-loss 9.41e-03, critic-loss 9.36e-02
# Episode 205, Steps 10300, BETA 0.6: actor-loss 2.58e-03, critic-loss 3.97e-02
# Episode 206, Steps 10350, BETA 0.6: actor-loss 2.76e-03, critic-loss 2.95e-02
# Episode 207, Steps 10400, BETA 0.6: actor-loss 9.95e-04, critic-loss 2.31e-02
# Episode 208, Steps 10450, BETA 0.6: actor-loss 4.65e-03, critic-loss 3.29e-02
# Episode 209, Steps 10500, BETA 0.6: actor-loss 1.52e-03, critic-loss 2.16e-02
# Episode 210, Steps 10550, BETA 0.6: actor-loss 2.51e-03, critic-loss 3.17e-02
# Episode 211, Steps 10600, BETA 0.6: actor-loss 2.49e-03, critic-loss 3.54e-02
# Episode 212, Steps 10650, BETA 0.6: actor-loss 2.15e-03, critic-loss 2.40e-02
# Episode 213, Steps 10700, BETA 0.6: actor-loss 2.41e-03, critic-loss 4.10e-02
# Episode 214, Steps 10750, BETA 0.6: actor-loss 1.20e-02, critic-loss 8.86e-02
# Episode 215, Steps 10800, BETA 0.6: actor-loss 5.86e-03, critic-loss 4.43e-02
# Episode 216, Steps 10850, BETA 0.6: actor-loss 1.39e-02, critic-loss 1.80e-01
# Episode 217, Steps 10900, BETA 0.6: actor-loss 1.53e-02, critic-loss 1.27e-01
# Episode 218, Steps 10950, BETA 0.6: actor-loss 1.05e-02, critic-loss 1.31e-01
# tensor([-10.3144])
# Episode 219, Steps 11000, BETA 0.6: actor-loss 3.54e-03, critic-loss 5.48e-02
# Episode 220, Steps 11050, BETA 0.6: actor-loss 3.45e-03, critic-loss 4.47e-02
# Episode 221, Steps 11100, BETA 0.6: actor-loss 9.01e-03, critic-loss 1.38e-01
# Episode 222, Steps 11150, BETA 0.6: actor-loss 1.29e-02, critic-loss 1.86e-01
# Episode 223, Steps 11200, BETA 0.6: actor-loss 6.01e-03, critic-loss 7.55e-02
# Episode 224, Steps 11250, BETA 0.6: actor-loss 4.55e-03, critic-loss 5.68e-02
# Episode 225, Steps 11300, BETA 0.6: actor-loss 2.37e-03, critic-loss 3.77e-02
# Episode 226, Steps 11350, BETA 0.6: actor-loss 2.55e-03, critic-loss 2.54e-02
# Episode 227, Steps 11400, BETA 0.6: actor-loss 1.35e-03, critic-loss 2.99e-02
# Episode 228, Steps 11450, BETA 0.6: actor-loss 5.47e-03, critic-loss 6.15e-02
# Episode 229, Steps 11500, BETA 0.6: actor-loss 1.03e-02, critic-loss 1.08e-01
# Episode 230, Steps 11550, BETA 0.6: actor-loss 4.79e-03, critic-loss 4.48e-02
# Episode 231, Steps 11600, BETA 0.6: actor-loss 3.38e-03, critic-loss 3.70e-02
# Episode 232, Steps 11650, BETA 0.6: actor-loss 6.29e-03, critic-loss 5.49e-02
# Episode 233, Steps 11700, BETA 0.6: actor-loss 5.00e-03, critic-loss 6.27e-02
# Episode 234, Steps 11750, BETA 0.6: actor-loss 5.66e-03, critic-loss 6.66e-02
# Episode 235, Steps 11800, BETA 0.6: actor-loss 1.12e-02, critic-loss 1.56e-01
# Episode 236, Steps 11850, BETA 0.6: actor-loss 1.02e-02, critic-loss 6.84e-02
# Episode 237, Steps 11900, BETA 0.6: actor-loss 5.50e-03, critic-loss 6.50e-02
# Episode 238, Steps 11950, BETA 0.6: actor-loss 9.46e-03, critic-loss 1.05e-01
# tensor([-11.2016])
# Episode 239, Steps 12000, BETA 0.6: actor-loss 1.89e-02, critic-loss 1.34e-01
# Episode 240, Steps 12050, BETA 0.6: actor-loss 4.03e-02, critic-loss 4.00e-01
# Episode 241, Steps 12100, BETA 0.6: actor-loss 6.79e-03, critic-loss 1.04e-01
# Episode 242, Steps 12150, BETA 0.6: actor-loss 1.59e-02, critic-loss 2.30e-01
# Episode 243, Steps 12200, BETA 0.6: actor-loss 8.25e-03, critic-loss 1.03e-01
# Episode 244, Steps 12250, BETA 0.6: actor-loss 4.38e-03, critic-loss 5.01e-02
# Episode 245, Steps 12300, BETA 0.6: actor-loss 8.56e-03, critic-loss 1.55e-01
# Episode 246, Steps 12350, BETA 0.6: actor-loss 5.88e-03, critic-loss 6.73e-02
# Episode 247, Steps 12400, BETA 0.6: actor-loss 4.99e-03, critic-loss 7.75e-02
# Episode 248, Steps 12450, BETA 0.6: actor-loss 6.58e-03, critic-loss 4.40e-02
# Episode 249, Steps 12500, BETA 0.6: actor-loss 3.00e-03, critic-loss 3.15e-02
# Episode 250, Steps 12550, BETA 0.6: actor-loss 2.72e-03, critic-loss 2.78e-02
# Episode 251, Steps 12600, BETA 0.6: actor-loss 2.28e-03, critic-loss 3.41e-02
# Episode 252, Steps 12650, BETA 0.6: actor-loss 2.93e-03, critic-loss 3.29e-02
# Episode 253, Steps 12700, BETA 0.6: actor-loss 2.11e-03, critic-loss 2.68e-02
# Episode 254, Steps 12750, BETA 0.6: actor-loss 4.21e-02, critic-loss 7.15e-01
# Episode 255, Steps 12800, BETA 0.6: actor-loss 1.52e-02, critic-loss 1.58e-01
# Episode 256, Steps 12850, BETA 0.6: actor-loss 2.45e-03, critic-loss 3.12e-02
# Episode 257, Steps 12900, BETA 0.6: actor-loss 6.27e-04, critic-loss 2.03e-02
# Episode 258, Steps 12950, BETA 0.6: actor-loss 2.56e-03, critic-loss 2.49e-02
# tensor([-7.5087])
# Episode 259, Steps 13000, BETA 0.6: actor-loss 1.21e-03, critic-loss 2.07e-02
# Episode 260, Steps 13050, BETA 0.6: actor-loss 1.97e-03, critic-loss 2.43e-02
# Episode 261, Steps 13100, BETA 0.6: actor-loss 1.14e-03, critic-loss 2.42e-02
# Episode 262, Steps 13150, BETA 0.6: actor-loss 2.38e-03, critic-loss 2.48e-02
# Episode 263, Steps 13200, BETA 0.6: actor-loss 3.34e-03, critic-loss 4.02e-02
# Episode 264, Steps 13250, BETA 0.6: actor-loss 8.84e-03, critic-loss 4.26e-02
# Episode 265, Steps 13300, BETA 0.6: actor-loss 4.06e-03, critic-loss 4.96e-02
# Episode 266, Steps 13350, BETA 0.6: actor-loss 6.45e-03, critic-loss 5.88e-02
# Episode 267, Steps 13400, BETA 0.6: actor-loss 3.04e-03, critic-loss 4.01e-02
# Episode 268, Steps 13450, BETA 0.6: actor-loss 3.29e-03, critic-loss 3.39e-02
# Episode 269, Steps 13500, BETA 0.6: actor-loss 3.01e-03, critic-loss 4.47e-02
# Episode 270, Steps 13550, BETA 0.6: actor-loss 8.92e-03, critic-loss 4.84e-02
# Episode 271, Steps 13600, BETA 0.6: actor-loss 4.42e-03, critic-loss 4.51e-02
# Episode 272, Steps 13650, BETA 0.6: actor-loss 1.31e-02, critic-loss 1.63e-01
# Episode 273, Steps 13700, BETA 0.6: actor-loss 2.26e-02, critic-loss 2.27e-01
# Episode 274, Steps 13750, BETA 0.6: actor-loss 3.41e-03, critic-loss 2.69e-02
# Episode 275, Steps 13800, BETA 0.6: actor-loss 2.49e-03, critic-loss 2.21e-02
# Episode 276, Steps 13850, BETA 0.6: actor-loss 7.32e-03, critic-loss 4.09e-02
# Episode 277, Steps 13900, BETA 0.6: actor-loss 5.79e-03, critic-loss 6.31e-02
# Episode 278, Steps 13950, BETA 0.6: actor-loss 1.33e-02, critic-loss 6.97e-02
# tensor([-9.6146])
# Episode 279, Steps 14000, BETA 0.6: actor-loss 1.10e-02, critic-loss 9.53e-02
# Episode 280, Steps 14050, BETA 0.6: actor-loss 4.09e-02, critic-loss 5.16e-01
# Episode 281, Steps 14100, BETA 0.6: actor-loss 7.95e-03, critic-loss 6.93e-02
# Episode 282, Steps 14150, BETA 0.6: actor-loss 4.19e-03, critic-loss 5.76e-02
# Episode 283, Steps 14200, BETA 0.6: actor-loss 1.74e-03, critic-loss 3.58e-02
# Episode 284, Steps 14250, BETA 0.6: actor-loss 1.27e-02, critic-loss 1.63e-01
# Episode 285, Steps 14300, BETA 0.6: actor-loss 7.27e-03, critic-loss 1.06e-01
# Episode 286, Steps 14350, BETA 0.6: actor-loss 3.34e-03, critic-loss 2.48e-02
# Episode 287, Steps 14400, BETA 0.6: actor-loss 1.00e-03, critic-loss 2.63e-02
# Episode 288, Steps 14450, BETA 0.6: actor-loss 4.68e-03, critic-loss 4.22e-02
# Episode 289, Steps 14500, BETA 0.6: actor-loss 8.15e-03, critic-loss 4.11e-02
# Episode 290, Steps 14550, BETA 0.6: actor-loss 5.37e-03, critic-loss 4.91e-02
# Episode 291, Steps 14600, BETA 0.6: actor-loss 4.22e-03, critic-loss 4.97e-02
# Episode 292, Steps 14650, BETA 0.6: actor-loss 5.18e-03, critic-loss 3.74e-02
# Episode 293, Steps 14700, BETA 0.6: actor-loss 2.56e-03, critic-loss 2.63e-02
# Episode 294, Steps 14750, BETA 0.6: actor-loss 3.44e-03, critic-loss 3.63e-02
# Episode 295, Steps 14800, BETA 0.6: actor-loss 2.65e-03, critic-loss 2.26e-02
# Episode 296, Steps 14850, BETA 0.6: actor-loss 8.80e-03, critic-loss 7.19e-02
# Episode 297, Steps 14900, BETA 0.6: actor-loss 1.36e-02, critic-loss 1.02e-01
# Episode 298, Steps 14950, BETA 0.6: actor-loss 1.92e-02, critic-loss 2.25e-01
# tensor([-10.4035])
# Episode 299, Steps 15000, BETA 0.6: actor-loss 9.67e-03, critic-loss 9.36e-02
# Episode 300, Steps 15050, BETA 0.6: actor-loss 2.73e-02, critic-loss 3.67e-01
# Episode 301, Steps 15100, BETA 0.6: actor-loss 6.43e-03, critic-loss 5.53e-02
# Episode 302, Steps 15150, BETA 0.6: actor-loss 4.53e-03, critic-loss 5.64e-02
# Episode 303, Steps 15200, BETA 0.6: actor-loss 1.31e-03, critic-loss 2.16e-02
# Episode 304, Steps 15250, BETA 0.6: actor-loss 2.78e-03, critic-loss 3.15e-02
# Episode 305, Steps 15300, BETA 0.6: actor-loss 2.54e-03, critic-loss 3.02e-02
# Episode 306, Steps 15350, BETA 0.6: actor-loss 5.40e-03, critic-loss 3.72e-02
# Episode 307, Steps 15400, BETA 0.6: actor-loss 4.84e-03, critic-loss 4.60e-02
# Episode 308, Steps 15450, BETA 0.6: actor-loss 4.24e-03, critic-loss 3.39e-02
# Episode 309, Steps 15500, BETA 0.6: actor-loss 1.30e-03, critic-loss 2.03e-02
# Episode 310, Steps 15550, BETA 0.6: actor-loss 2.08e-03, critic-loss 1.89e-02
# Episode 311, Steps 15600, BETA 0.6: actor-loss 3.22e-03, critic-loss 3.69e-02
# Episode 312, Steps 15650, BETA 0.6: actor-loss 8.45e-03, critic-loss 6.62e-02
# Episode 313, Steps 15700, BETA 0.6: actor-loss 3.33e-02, critic-loss 3.39e-01
# Episode 314, Steps 15750, BETA 0.6: actor-loss 1.71e-02, critic-loss 8.95e-02
# Episode 315, Steps 15800, BETA 0.6: actor-loss 4.02e-03, critic-loss 4.45e-02
# Episode 316, Steps 15850, BETA 0.6: actor-loss 4.49e-03, critic-loss 3.90e-02
# Episode 317, Steps 15900, BETA 0.6: actor-loss 1.65e-03, critic-loss 3.08e-02
# Episode 318, Steps 15950, BETA 0.6: actor-loss 2.70e-03, critic-loss 2.58e-02
# tensor([-8.2904])
# Episode 319, Steps 16000, BETA 0.6: actor-loss 3.34e-03, critic-loss 2.50e-02
# Episode 320, Steps 16050, BETA 0.6: actor-loss 1.86e-02, critic-loss 1.74e-01
# Episode 321, Steps 16100, BETA 0.6: actor-loss 1.01e-02, critic-loss 3.36e-02
# Episode 322, Steps 16150, BETA 0.6: actor-loss 5.08e-03, critic-loss 4.46e-02
# Episode 323, Steps 16200, BETA 0.6: actor-loss 2.88e-03, critic-loss 2.83e-02
# Episode 324, Steps 16250, BETA 0.6: actor-loss 2.86e-03, critic-loss 3.12e-02
# Episode 325, Steps 16300, BETA 0.6: actor-loss 1.68e-02, critic-loss 1.86e-01
# Episode 326, Steps 16350, BETA 0.6: actor-loss 2.77e-02, critic-loss 1.60e-01
# Episode 327, Steps 16400, BETA 0.6: actor-loss 2.65e-02, critic-loss 4.07e-01
# Episode 328, Steps 16450, BETA 0.6: actor-loss 2.61e-02, critic-loss 2.21e-01
# Episode 329, Steps 16500, BETA 0.6: actor-loss 6.66e-03, critic-loss 8.02e-02
# Episode 330, Steps 16550, BETA 0.6: actor-loss 1.57e-02, critic-loss 1.14e-01
# Episode 331, Steps 16600, BETA 0.6: actor-loss 1.18e-02, critic-loss 6.46e-02
# Episode 332, Steps 16650, BETA 0.6: actor-loss 7.93e-03, critic-loss 6.58e-02
# Episode 333, Steps 16700, BETA 0.6: actor-loss 1.80e-03, critic-loss 4.56e-02
# Episode 334, Steps 16750, BETA 0.6: actor-loss 6.65e-03, critic-loss 8.05e-02
# Episode 335, Steps 16800, BETA 0.6: actor-loss 6.54e-03, critic-loss 9.29e-02
# Episode 336, Steps 16850, BETA 0.6: actor-loss 6.54e-03, critic-loss 4.61e-02
# Episode 337, Steps 16900, BETA 0.6: actor-loss 4.80e-03, critic-loss 5.72e-02
# Episode 338, Steps 16950, BETA 0.6: actor-loss 1.13e-02, critic-loss 5.19e-02
# tensor([-7.2071])
# Episode 339, Steps 17000, BETA 0.6: actor-loss 2.89e-03, critic-loss 3.76e-02
# Episode 340, Steps 17050, BETA 0.6: actor-loss 3.68e-03, critic-loss 4.04e-02
# Episode 341, Steps 17100, BETA 0.6: actor-loss 2.77e-03, critic-loss 4.18e-02
# Episode 342, Steps 17150, BETA 0.6: actor-loss 8.30e-03, critic-loss 6.06e-02
# Episode 343, Steps 17200, BETA 0.6: actor-loss 2.09e-03, critic-loss 4.15e-02
# Episode 344, Steps 17250, BETA 0.6: actor-loss 6.08e-02, critic-loss 7.23e-01
# Episode 345, Steps 17300, BETA 0.6: actor-loss 4.10e-02, critic-loss 1.67e-01
# Episode 346, Steps 17350, BETA 0.6: actor-loss 3.61e-03, critic-loss 3.77e-02
# Episode 347, Steps 17400, BETA 0.6: actor-loss 2.63e-03, critic-loss 4.01e-02
# Episode 348, Steps 17450, BETA 0.6: actor-loss 5.07e-03, critic-loss 4.20e-02
# Episode 349, Steps 17500, BETA 0.6: actor-loss 2.57e-03, critic-loss 4.46e-02
# Episode 350, Steps 17550, BETA 0.6: actor-loss 4.29e-03, critic-loss 4.65e-02
# Episode 351, Steps 17600, BETA 0.6: actor-loss 3.14e-03, critic-loss 4.58e-02
# Episode 352, Steps 17650, BETA 0.6: actor-loss 1.42e-02, critic-loss 1.81e-01
# Episode 353, Steps 17700, BETA 0.6: actor-loss 1.18e-02, critic-loss 1.34e-01
# Episode 354, Steps 17750, BETA 0.6: actor-loss 7.23e-03, critic-loss 5.48e-02
# Episode 355, Steps 17800, BETA 0.6: actor-loss 2.87e-03, critic-loss 4.81e-02
# Episode 356, Steps 17850, BETA 0.6: actor-loss 1.90e-02, critic-loss 8.29e-02
# Episode 357, Steps 17900, BETA 0.6: actor-loss 2.49e-02, critic-loss 6.41e-02
# Episode 358, Steps 17950, BETA 0.6: actor-loss 5.06e-03, critic-loss 5.71e-02
# tensor([-10.6432])
# Episode 359, Steps 18000, BETA 0.6: actor-loss 2.84e-03, critic-loss 5.30e-02
# Episode 360, Steps 18050, BETA 0.6: actor-loss 5.56e-03, critic-loss 6.23e-02
# Episode 361, Steps 18100, BETA 0.6: actor-loss 5.14e-03, critic-loss 7.43e-02
# Episode 362, Steps 18150, BETA 0.6: actor-loss 3.87e-03, critic-loss 3.82e-02
# Episode 363, Steps 18200, BETA 0.6: actor-loss 6.36e-03, critic-loss 7.20e-02
# Episode 364, Steps 18250, BETA 0.6: actor-loss 2.75e-02, critic-loss 2.88e-01
# Episode 365, Steps 18300, BETA 0.6: actor-loss 2.87e-02, critic-loss 2.56e-01
# Episode 366, Steps 18350, BETA 0.6: actor-loss 6.76e-03, critic-loss 6.72e-02
# Episode 367, Steps 18400, BETA 0.6: actor-loss 1.72e-03, critic-loss 3.97e-02
# Episode 368, Steps 18450, BETA 0.6: actor-loss 4.43e-03, critic-loss 3.40e-02
# Episode 369, Steps 18500, BETA 0.6: actor-loss 6.01e-03, critic-loss 3.04e-02
# Episode 370, Steps 18550, BETA 0.6: actor-loss 5.92e-03, critic-loss 3.91e-02
# Episode 371, Steps 18600, BETA 0.6: actor-loss 3.69e-03, critic-loss 3.03e-02
# Episode 372, Steps 18650, BETA 0.6: actor-loss 3.48e-03, critic-loss 3.70e-02
# Episode 373, Steps 18700, BETA 0.6: actor-loss 6.61e-03, critic-loss 4.07e-02
# Episode 374, Steps 18750, BETA 0.6: actor-loss 6.12e-03, critic-loss 4.14e-02
# Episode 375, Steps 18800, BETA 0.6: actor-loss 6.97e-03, critic-loss 3.00e-02
# Episode 376, Steps 18850, BETA 0.6: actor-loss 1.97e-02, critic-loss 7.10e-02
# Episode 377, Steps 18900, BETA 0.6: actor-loss 5.34e-03, critic-loss 3.55e-02
# Episode 378, Steps 18950, BETA 0.6: actor-loss 9.64e-03, critic-loss 5.64e-02
# tensor([-7.6826])
# Episode 379, Steps 19000, BETA 0.6: actor-loss 1.64e-02, critic-loss 1.08e-01
# Episode 380, Steps 19050, BETA 0.6: actor-loss 1.71e-02, critic-loss 1.61e-01
# Episode 381, Steps 19100, BETA 0.6: actor-loss 7.56e-03, critic-loss 6.96e-02
# Episode 382, Steps 19150, BETA 0.6: actor-loss 6.07e-03, critic-loss 6.68e-02
# Episode 383, Steps 19200, BETA 0.6: actor-loss 7.21e-03, critic-loss 6.22e-02
# Episode 384, Steps 19250, BETA 0.6: actor-loss 6.46e-03, critic-loss 4.00e-02
# Episode 385, Steps 19300, BETA 0.6: actor-loss 5.02e-03, critic-loss 4.24e-02
# Episode 386, Steps 19350, BETA 0.6: actor-loss 5.85e-03, critic-loss 2.81e-02
# Episode 387, Steps 19400, BETA 0.6: actor-loss 5.88e-03, critic-loss 3.96e-02
# Episode 388, Steps 19450, BETA 0.6: actor-loss 1.04e-02, critic-loss 5.94e-02
# Episode 389, Steps 19500, BETA 0.6: actor-loss 7.15e-03, critic-loss 4.08e-02
# Episode 390, Steps 19550, BETA 0.6: actor-loss 8.75e-03, critic-loss 5.49e-02
# Episode 391, Steps 19600, BETA 0.6: actor-loss 8.44e-03, critic-loss 8.32e-02
# Episode 392, Steps 19650, BETA 0.6: actor-loss 5.82e-03, critic-loss 4.24e-02
# Episode 393, Steps 19700, BETA 0.6: actor-loss 5.09e-03, critic-loss 7.21e-02
# Episode 394, Steps 19750, BETA 0.6: actor-loss 7.70e-02, critic-loss 5.94e-01
# Episode 395, Steps 19800, BETA 0.6: actor-loss 9.55e-03, critic-loss 6.64e-02
# Episode 396, Steps 19850, BETA 0.6: actor-loss 4.28e-03, critic-loss 4.73e-02
# Episode 397, Steps 19900, BETA 0.6: actor-loss 1.40e-03, critic-loss 3.45e-02
# Episode 398, Steps 19950, BETA 0.6: actor-loss 5.86e-03, critic-loss 5.29e-02
# tensor([-7.2527])
# Episode 399, Steps 20000, BETA 0.6: actor-loss 1.33e-02, critic-loss 4.70e-02
# Episode 400, Steps 20050, BETA 0.6: actor-loss 1.07e-02, critic-loss 9.07e-02
# Episode 401, Steps 20100, BETA 0.6: actor-loss 4.95e-03, critic-loss 4.16e-02
# Episode 402, Steps 20150, BETA 0.6: actor-loss 7.19e-03, critic-loss 5.60e-02
# Episode 403, Steps 20200, BETA 0.6: actor-loss 2.27e-03, critic-loss 3.48e-02
# Episode 404, Steps 20250, BETA 0.6: actor-loss 7.09e-03, critic-loss 4.04e-02
# Episode 405, Steps 20300, BETA 0.6: actor-loss 3.22e-03, critic-loss 3.44e-02
# Episode 406, Steps 20350, BETA 0.6: actor-loss 1.47e-02, critic-loss 8.85e-02
# Episode 407, Steps 20400, BETA 0.6: actor-loss 7.25e-03, critic-loss 5.65e-02
# Episode 408, Steps 20450, BETA 0.6: actor-loss 2.18e-02, critic-loss 1.34e-01
# Episode 409, Steps 20500, BETA 0.6: actor-loss 7.57e-03, critic-loss 6.54e-02
# Episode 410, Steps 20550, BETA 0.6: actor-loss 5.68e-03, critic-loss 4.98e-02
# Episode 411, Steps 20600, BETA 0.6: actor-loss 5.84e-03, critic-loss 6.68e-02
# Episode 412, Steps 20650, BETA 0.6: actor-loss 9.00e-03, critic-loss 4.05e-02
# Episode 413, Steps 20700, BETA 0.6: actor-loss 1.01e-02, critic-loss 5.92e-02
# Episode 414, Steps 20750, BETA 0.6: actor-loss 4.39e-03, critic-loss 3.79e-02
# Episode 415, Steps 20800, BETA 0.6: actor-loss 6.76e-03, critic-loss 5.07e-02
# Episode 416, Steps 20850, BETA 0.6: actor-loss 7.58e-03, critic-loss 2.47e-02
# Episode 417, Steps 20900, BETA 0.6: actor-loss 1.42e-03, critic-loss 1.53e-02
# Episode 418, Steps 20950, BETA 0.6: actor-loss 2.61e-03, critic-loss 2.44e-02
# tensor([-4.6560])
# Episode 419, Steps 21000, BETA 0.6: actor-loss 2.13e-03, critic-loss 2.58e-02
# Episode 420, Steps 21050, BETA 0.6: actor-loss 5.16e-03, critic-loss 3.62e-02
# Episode 421, Steps 21100, BETA 0.6: actor-loss 7.78e-03, critic-loss 3.26e-02
# Episode 422, Steps 21150, BETA 0.6: actor-loss 3.65e-02, critic-loss 1.00e-01
# Episode 423, Steps 21200, BETA 0.6: actor-loss 1.09e-02, critic-loss 4.58e-02
# Episode 424, Steps 21250, BETA 0.6: actor-loss 4.65e-03, critic-loss 3.19e-02
# Episode 425, Steps 21300, BETA 0.6: actor-loss 3.88e-03, critic-loss 3.41e-02
# Episode 426, Steps 21350, BETA 0.6: actor-loss 6.49e-03, critic-loss 4.12e-02
# Episode 427, Steps 21400, BETA 0.6: actor-loss 3.90e-02, critic-loss 4.52e-01
# Episode 428, Steps 21450, BETA 0.6: actor-loss 2.67e-01, critic-loss 2.92e+00
# Episode 429, Steps 21500, BETA 0.6: actor-loss 2.66e-02, critic-loss 1.62e-01
# Episode 430, Steps 21550, BETA 0.6: actor-loss 4.76e-03, critic-loss 5.30e-02
# Episode 431, Steps 21600, BETA 0.6: actor-loss 1.11e-03, critic-loss 4.84e-02
# Episode 432, Steps 21650, BETA 0.6: actor-loss 3.92e-03, critic-loss 5.48e-02
# Episode 433, Steps 21700, BETA 0.6: actor-loss 1.35e-03, critic-loss 4.29e-02
# Episode 434, Steps 21750, BETA 0.6: actor-loss 2.88e-03, critic-loss 3.13e-02
# Episode 435, Steps 21800, BETA 0.6: actor-loss 7.94e-04, critic-loss 2.45e-02
# Episode 436, Steps 21850, BETA 0.6: actor-loss 3.85e-03, critic-loss 1.95e-02
# Episode 437, Steps 21900, BETA 0.6: actor-loss 6.31e-04, critic-loss 1.68e-02
# Episode 438, Steps 21950, BETA 0.6: actor-loss 1.87e-03, critic-loss 1.91e-02
# tensor([-8.9854])
# Episode 439, Steps 22000, BETA 0.6: actor-loss 1.03e-03, critic-loss 1.43e-02
# Episode 440, Steps 22050, BETA 0.6: actor-loss 1.86e-03, critic-loss 2.04e-02
# Episode 441, Steps 22100, BETA 0.6: actor-loss 1.47e-03, critic-loss 2.18e-02
# Episode 442, Steps 22150, BETA 0.6: actor-loss 7.15e-03, critic-loss 4.22e-02
# Episode 443, Steps 22200, BETA 0.6: actor-loss 9.04e-03, critic-loss 4.45e-02
# Episode 444, Steps 22250, BETA 0.6: actor-loss 6.12e-03, critic-loss 4.57e-02
# Episode 445, Steps 22300, BETA 0.6: actor-loss 2.48e-03, critic-loss 3.45e-02
# Episode 446, Steps 22350, BETA 0.6: actor-loss 3.95e-03, critic-loss 2.20e-02
# Episode 447, Steps 22400, BETA 0.6: actor-loss 2.56e-03, critic-loss 2.13e-02
# Episode 448, Steps 22450, BETA 0.6: actor-loss 2.78e-03, critic-loss 2.53e-02
# Episode 449, Steps 22500, BETA 0.6: actor-loss 3.23e-03, critic-loss 4.00e-02
# Episode 450, Steps 22550, BETA 0.6: actor-loss 4.89e-03, critic-loss 3.10e-02
# Episode 451, Steps 22600, BETA 0.6: actor-loss 1.10e-02, critic-loss 2.94e-02
# Episode 452, Steps 22650, BETA 0.6: actor-loss 6.85e-03, critic-loss 3.92e-02
# Episode 453, Steps 22700, BETA 0.6: actor-loss 5.62e-02, critic-loss 3.06e-01
# Episode 454, Steps 22750, BETA 0.6: actor-loss 1.54e-02, critic-loss 1.21e-01
# Episode 455, Steps 22800, BETA 0.6: actor-loss 3.60e-03, critic-loss 4.52e-02
# Episode 456, Steps 22850, BETA 0.6: actor-loss 8.29e-03, critic-loss 6.12e-02
# Episode 457, Steps 22900, BETA 0.6: actor-loss 5.58e-03, critic-loss 5.17e-02
# Episode 458, Steps 22950, BETA 0.6: actor-loss 1.74e-02, critic-loss 8.52e-02
# tensor([-6.6299])
# Episode 459, Steps 23000, BETA 0.6: actor-loss 1.09e-02, critic-loss 4.08e-02
# Episode 460, Steps 23050, BETA 0.6: actor-loss 3.12e-03, critic-loss 3.45e-02
# Episode 461, Steps 23100, BETA 0.6: actor-loss 3.75e-03, critic-loss 4.09e-02
# Episode 462, Steps 23150, BETA 0.6: actor-loss 3.03e-03, critic-loss 2.60e-02
# Episode 463, Steps 23200, BETA 0.6: actor-loss 2.77e-03, critic-loss 2.35e-02
# Episode 464, Steps 23250, BETA 0.6: actor-loss 7.35e-03, critic-loss 2.10e-02
# Episode 465, Steps 23300, BETA 0.6: actor-loss 1.76e-02, critic-loss 1.57e-01
# Episode 466, Steps 23350, BETA 0.6: actor-loss 8.98e-03, critic-loss 7.44e-02
# Episode 467, Steps 23400, BETA 0.6: actor-loss 3.68e-03, critic-loss 3.93e-02
# Episode 468, Steps 23450, BETA 0.6: actor-loss 8.95e-03, critic-loss 5.09e-02
# Episode 469, Steps 23500, BETA 0.6: actor-loss 4.59e-03, critic-loss 2.39e-02
# Episode 470, Steps 23550, BETA 0.6: actor-loss 6.43e-03, critic-loss 1.98e-02
# Episode 471, Steps 23600, BETA 0.6: actor-loss 3.95e-03, critic-loss 1.55e-02
# Episode 472, Steps 23650, BETA 0.6: actor-loss 1.13e-02, critic-loss 2.06e-02
# Episode 473, Steps 23700, BETA 0.6: actor-loss 5.42e-03, critic-loss 3.74e-02
# Episode 474, Steps 23750, BETA 0.6: actor-loss 9.79e-03, critic-loss 5.92e-02
# Episode 475, Steps 23800, BETA 0.6: actor-loss 1.93e-02, critic-loss 7.29e-02
# Episode 476, Steps 23850, BETA 0.6: actor-loss 1.26e-02, critic-loss 5.29e-02
# Episode 477, Steps 23900, BETA 0.6: actor-loss 1.61e-02, critic-loss 8.54e-02
# Episode 478, Steps 23950, BETA 0.6: actor-loss 3.58e-01, critic-loss 1.83e+00
# tensor([-8.3123])
# Episode 479, Steps 24000, BETA 0.6: actor-loss 2.64e-02, critic-loss 2.19e-01
# Episode 480, Steps 24050, BETA 0.6: actor-loss 1.02e-02, critic-loss 1.45e-01
# Episode 481, Steps 24100, BETA 0.6: actor-loss 3.06e-03, critic-loss 1.06e-01
# Episode 482, Steps 24150, BETA 0.6: actor-loss 1.03e-02, critic-loss 1.14e-01
# Episode 483, Steps 24200, BETA 0.6: actor-loss 5.10e-03, critic-loss 6.87e-02
# Episode 484, Steps 24250, BETA 0.6: actor-loss 6.03e-03, critic-loss 7.51e-02
# Episode 485, Steps 24300, BETA 0.6: actor-loss 4.70e-03, critic-loss 8.84e-02
# Episode 486, Steps 24350, BETA 0.6: actor-loss 4.19e-03, critic-loss 4.26e-02
# Episode 487, Steps 24400, BETA 0.6: actor-loss 1.61e-03, critic-loss 4.32e-02
# Episode 488, Steps 24450, BETA 0.6: actor-loss 5.31e-03, critic-loss 3.77e-02
# Episode 489, Steps 24500, BETA 0.6: actor-loss 2.55e-03, critic-loss 4.21e-02
# Episode 490, Steps 24550, BETA 0.6: actor-loss 3.63e-03, critic-loss 4.37e-02
# Episode 491, Steps 24600, BETA 0.6: actor-loss 1.02e-02, critic-loss 7.70e-02
# Episode 492, Steps 24650, BETA 0.6: actor-loss 1.75e-02, critic-loss 1.04e-01
# Episode 493, Steps 24700, BETA 0.6: actor-loss 1.02e-02, critic-loss 6.09e-02
# Episode 494, Steps 24750, BETA 0.6: actor-loss 2.87e-03, critic-loss 2.56e-02
# Episode 495, Steps 24800, BETA 0.6: actor-loss 6.76e-04, critic-loss 1.23e-02
# Episode 496, Steps 24850, BETA 0.6: actor-loss 1.56e-03, critic-loss 1.52e-02
# Episode 497, Steps 24900, BETA 0.6: actor-loss 2.26e-03, critic-loss 1.55e-02
# Episode 498, Steps 24950, BETA 0.6: actor-loss 1.08e-02, critic-loss 1.82e-02
# tensor([-4.4636])
# Episode 499, Steps 25000, BETA 0.6: actor-loss 2.38e-03, critic-loss 2.45e-02
# Episode 500, Steps 25050, BETA 0.6: actor-loss 6.07e-03, critic-loss 4.74e-02
# Episode 501, Steps 25100, BETA 0.6: actor-loss 1.80e-02, critic-loss 6.11e-02
# Episode 502, Steps 25150, BETA 0.6: actor-loss 3.46e-03, critic-loss 2.38e-02
# Episode 503, Steps 25200, BETA 0.6: actor-loss 9.32e-04, critic-loss 1.54e-02
# Episode 504, Steps 25250, BETA 0.6: actor-loss 5.29e-03, critic-loss 2.12e-02
# Episode 505, Steps 25300, BETA 0.6: actor-loss 5.59e-03, critic-loss 1.99e-02
# Episode 506, Steps 25350, BETA 0.6: actor-loss 3.94e-03, critic-loss 2.05e-02
# Episode 507, Steps 25400, BETA 0.6: actor-loss 4.16e-03, critic-loss 2.70e-02
# Episode 508, Steps 25450, BETA 0.6: actor-loss 1.02e-02, critic-loss 8.15e-02
# Episode 509, Steps 25500, BETA 0.6: actor-loss 3.34e-02, critic-loss 1.61e-01
# Episode 510, Steps 25550, BETA 0.6: actor-loss 4.81e-03, critic-loss 2.26e-02
# Episode 511, Steps 25600, BETA 0.6: actor-loss 2.29e-03, critic-loss 4.40e-02
# Episode 512, Steps 25650, BETA 0.6: actor-loss 3.22e-03, critic-loss 3.45e-02
# Episode 513, Steps 25700, BETA 0.6: actor-loss 2.63e-03, critic-loss 2.59e-02
# Episode 514, Steps 25750, BETA 0.6: actor-loss 1.09e-02, critic-loss 4.79e-02
# Episode 515, Steps 25800, BETA 0.6: actor-loss 1.43e-02, critic-loss 2.86e-02
# Episode 516, Steps 25850, BETA 0.6: actor-loss 7.02e-03, critic-loss 2.28e-02
# Episode 517, Steps 25900, BETA 0.6: actor-loss 2.15e-03, critic-loss 2.09e-02
# Episode 518, Steps 25950, BETA 0.6: actor-loss 3.73e-03, critic-loss 3.10e-02
# tensor([-4.3544])
# Episode 519, Steps 26000, BETA 0.6: actor-loss 2.07e-03, critic-loss 3.44e-02
# Episode 520, Steps 26050, BETA 0.6: actor-loss 3.67e-03, critic-loss 3.98e-02
# Episode 521, Steps 26100, BETA 0.6: actor-loss 1.30e-02, critic-loss 1.46e-01
# Episode 522, Steps 26150, BETA 0.6: actor-loss 3.05e-02, critic-loss 1.69e-01
# Episode 523, Steps 26200, BETA 0.6: actor-loss 3.38e-02, critic-loss 1.23e-01
# Episode 524, Steps 26250, BETA 0.6: actor-loss 3.92e-03, critic-loss 2.92e-02
# Episode 525, Steps 26300, BETA 0.6: actor-loss 3.18e-03, critic-loss 3.42e-02
# Episode 526, Steps 26350, BETA 0.6: actor-loss 1.73e-02, critic-loss 1.13e-01
# Episode 527, Steps 26400, BETA 0.6: actor-loss 8.37e-03, critic-loss 5.55e-02
# Episode 528, Steps 26450, BETA 0.6: actor-loss 2.62e-02, critic-loss 1.49e-01
# Episode 529, Steps 26500, BETA 0.6: actor-loss 2.64e-02, critic-loss 7.69e-02
# Episode 530, Steps 26550, BETA 0.6: actor-loss 1.29e-02, critic-loss 8.19e-02
# Episode 531, Steps 26600, BETA 0.6: actor-loss 8.90e-03, critic-loss 4.82e-02
# Episode 532, Steps 26650, BETA 0.6: actor-loss 9.39e-03, critic-loss 3.42e-02
# Episode 533, Steps 26700, BETA 0.6: actor-loss 9.98e-03, critic-loss 2.83e-02
# Episode 534, Steps 26750, BETA 0.6: actor-loss 9.38e-03, critic-loss 6.05e-02
# Episode 535, Steps 26800, BETA 0.6: actor-loss 8.87e-03, critic-loss 1.09e-01
# Episode 536, Steps 26850, BETA 0.6: actor-loss 2.24e-02, critic-loss 1.88e-01
# Episode 537, Steps 26900, BETA 0.6: actor-loss 5.75e-03, critic-loss 6.65e-02
# Episode 538, Steps 26950, BETA 0.6: actor-loss 4.96e-02, critic-loss 4.49e-01
# tensor([-4.8733])
# Episode 539, Steps 27000, BETA 0.6: actor-loss 2.32e-02, critic-loss 1.47e-01
# Episode 540, Steps 27050, BETA 0.6: actor-loss 4.80e-03, critic-loss 4.67e-02
# Episode 541, Steps 27100, BETA 0.6: actor-loss 1.68e-03, critic-loss 3.20e-02
# Episode 542, Steps 27150, BETA 0.6: actor-loss 3.41e-03, critic-loss 2.75e-02
# Episode 543, Steps 27200, BETA 0.6: actor-loss 1.18e-03, critic-loss 1.87e-02
# Episode 544, Steps 27250, BETA 0.6: actor-loss 4.17e-03, critic-loss 2.25e-02
# Episode 545, Steps 27300, BETA 0.6: actor-loss 1.91e-03, critic-loss 2.41e-02
# Episode 546, Steps 27350, BETA 0.6: actor-loss 3.42e-03, critic-loss 2.59e-02
# Episode 547, Steps 27400, BETA 0.6: actor-loss 2.30e-03, critic-loss 2.98e-02
# Episode 548, Steps 27450, BETA 0.6: actor-loss 4.40e-03, critic-loss 4.31e-02
# Episode 549, Steps 27500, BETA 0.6: actor-loss 1.16e-02, critic-loss 5.40e-02
# Episode 550, Steps 27550, BETA 0.6: actor-loss 8.44e-03, critic-loss 4.69e-02
# Episode 551, Steps 27600, BETA 0.6: actor-loss 3.31e-03, critic-loss 1.43e-02
# Episode 552, Steps 27650, BETA 0.6: actor-loss 1.64e-03, critic-loss 1.26e-02
# Episode 553, Steps 27700, BETA 0.6: actor-loss 7.05e-04, critic-loss 1.26e-02
# Episode 554, Steps 27750, BETA 0.6: actor-loss 3.04e-03, critic-loss 1.49e-02
# Episode 555, Steps 27800, BETA 0.6: actor-loss 3.74e-03, critic-loss 1.99e-02
# Episode 556, Steps 27850, BETA 0.6: actor-loss 2.84e-02, critic-loss 5.29e-02
# Episode 557, Steps 27900, BETA 0.6: actor-loss 1.16e-02, critic-loss 6.85e-02
# Episode 558, Steps 27950, BETA 0.6: actor-loss 5.89e-03, critic-loss 2.82e-02
# tensor([-4.6911])
# Episode 559, Steps 28000, BETA 0.6: actor-loss 3.92e-03, critic-loss 3.02e-02
# Episode 560, Steps 28050, BETA 0.6: actor-loss 4.80e-03, critic-loss 2.73e-02
# Episode 561, Steps 28100, BETA 0.6: actor-loss 3.32e-03, critic-loss 1.33e-02
# Episode 562, Steps 28150, BETA 0.6: actor-loss 9.61e-03, critic-loss 4.92e-02
# Episode 563, Steps 28200, BETA 0.6: actor-loss 2.18e-02, critic-loss 1.53e-01
# Episode 564, Steps 28250, BETA 0.6: actor-loss 1.50e-02, critic-loss 5.49e-02
# Episode 565, Steps 28300, BETA 0.6: actor-loss 4.79e-03, critic-loss 3.89e-02
# Episode 566, Steps 28350, BETA 0.6: actor-loss 6.63e-03, critic-loss 4.45e-02
# Episode 567, Steps 28400, BETA 0.6: actor-loss 2.69e-02, critic-loss 7.04e-02
# Episode 568, Steps 28450, BETA 0.6: actor-loss 3.05e-02, critic-loss 1.33e-01
# Episode 569, Steps 28500, BETA 0.6: actor-loss 2.57e-02, critic-loss 1.19e-01
# Episode 570, Steps 28550, BETA 0.6: actor-loss 1.42e-01, critic-loss 6.96e-01
# Episode 571, Steps 28600, BETA 0.6: actor-loss 5.60e-02, critic-loss 1.28e-01
# Episode 572, Steps 28650, BETA 0.6: actor-loss 5.03e-03, critic-loss 5.88e-02
# Episode 573, Steps 28700, BETA 0.6: actor-loss 6.89e-03, critic-loss 1.07e-01
# Episode 574, Steps 28750, BETA 0.6: actor-loss 6.02e-03, critic-loss 8.63e-02
# Episode 575, Steps 28800, BETA 0.6: actor-loss 2.64e-03, critic-loss 7.57e-02
# Episode 576, Steps 28850, BETA 0.6: actor-loss 1.83e-02, critic-loss 1.53e-01
# Episode 577, Steps 28900, BETA 0.6: actor-loss 1.57e-02, critic-loss 7.95e-02
# Episode 578, Steps 28950, BETA 0.6: actor-loss 1.51e-02, critic-loss 7.40e-02
# tensor([-4.4996])
# Episode 579, Steps 29000, BETA 0.6: actor-loss 7.20e-02, critic-loss 6.21e-02
# Episode 580, Steps 29050, BETA 0.6: actor-loss 1.36e-02, critic-loss 1.01e-01
# Episode 581, Steps 29100, BETA 0.6: actor-loss 5.31e-02, critic-loss 3.87e-01
# Episode 582, Steps 29150, BETA 0.6: actor-loss 9.19e-03, critic-loss 9.99e-02
# Episode 583, Steps 29200, BETA 0.6: actor-loss 5.19e-03, critic-loss 6.29e-02
# Episode 584, Steps 29250, BETA 0.6: actor-loss 6.03e-02, critic-loss 5.76e-01
# Episode 585, Steps 29300, BETA 0.6: actor-loss 1.40e-02, critic-loss 1.94e-01
# Episode 586, Steps 29350, BETA 0.6: actor-loss 7.14e-03, critic-loss 8.89e-02
# Episode 587, Steps 29400, BETA 0.6: actor-loss 2.94e-03, critic-loss 6.00e-02
# Episode 588, Steps 29450, BETA 0.6: actor-loss 1.38e-02, critic-loss 6.41e-02
# Episode 589, Steps 29500, BETA 0.6: actor-loss 5.57e-03, critic-loss 5.18e-02
# Episode 590, Steps 29550, BETA 0.6: actor-loss 4.05e-03, critic-loss 3.67e-02
# Episode 591, Steps 29600, BETA 0.6: actor-loss 2.64e-03, critic-loss 5.30e-02
# Episode 592, Steps 29650, BETA 0.6: actor-loss 1.37e-02, critic-loss 9.14e-02
# Episode 593, Steps 29700, BETA 0.6: actor-loss 7.80e-03, critic-loss 7.92e-02
# Episode 594, Steps 29750, BETA 0.6: actor-loss 8.14e-03, critic-loss 1.09e-01
# Episode 595, Steps 29800, BETA 0.6: actor-loss 7.32e-03, critic-loss 1.08e-01
# Episode 596, Steps 29850, BETA 0.6: actor-loss 9.71e-03, critic-loss 7.47e-02
# Episode 597, Steps 29900, BETA 0.6: actor-loss 4.10e-03, critic-loss 5.00e-02
# Episode 598, Steps 29950, BETA 0.6: actor-loss 5.58e-03, critic-loss 4.61e-02
# tensor([-4.5548])
# Episode 599, Steps 30000, BETA 0.6: actor-loss 5.43e-03, critic-loss 5.34e-02
#
# Complete

# %%
#@title Plot accumulated reward
plt.plot(acc_reward)
plt.hlines(-5,0,len(acc_reward)-1)
plt.grid()
plt.show()

# %%
#@title Simulate Trajectory
T_test = 100
r, x = test()
plt.plot(x[:,0],x[:,2])
plt.show()

# %%
#@title Simulate Cartpole
trajec = x
i = 0;
while i < T_test:
    angle = trajec[i, 2]
    car_pos = torch.tensor([trajec[i, 0], 0])
    pend_pos = car_pos+torch.tensor([0.6*torch.cos(angle+pi/2), 0.6*torch.sin(angle+pi/2)])
    plt.plot([car_pos[0]-0.3, car_pos[0]+0.3, car_pos[0]+0.3, car_pos[0]-0.3, car_pos[0]-0.3],
        [car_pos[1]+0.2, car_pos[1]+0.2, car_pos[1]-0.2, car_pos[1]-0.2, car_pos[1]+0.2],'b')
    plt.plot([car_pos[0]+0.3, car_pos[0]-0.3],[car_pos[1]-0.2, car_pos[1]-0.2], 'ob')
    plt.plot([car_pos[0], pend_pos[0]], [car_pos[1], pend_pos[1]], '-or')
    plt.xlim([-7, 7])
    plt.ylim([-7, 7])
    plt.show()
    
    clear_output(wait=True)
    time.sleep(0.09)  
    i += 1
